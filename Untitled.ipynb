# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.4.4

# %%
import os

# %%
cwd = os.getcwd()

# %%
print(cwd)
# Out:
# /Users/oleksandrbiruk/Jupyter Projects/Movies

# %%
data = pd.read_csv('1.csv', on_bad_lines='skip')

# %%
data = pd.read_csv('ratings_votes.csv', on_bad_lines='skip')

# %%
data = pd.read_csv('ratings_votes.csv', sep='\t')
# Out:
# /var/folders/yb/kt66bbqd7t7cb20rqwtk1yj40000gn/T/ipykernel_5193/2545333491.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('ratings_votes.csv', sep='\t')

# %%
print(data)
# Out:
#             tconst  averageRating  numVotes startYear endYear  \
# 0        tt0000001            5.7      1936      1894      \N
# 1        tt0000002            5.8       262      1892      \N
# 2        tt0000003            6.5      1760      1892      \N
# 3        tt0000004            5.6       177      1892      \N
# 4        tt0000005            6.2      2570      1893      \N
# ...            ...            ...       ...       ...     ...
# 1265780  tt9916682            6.4         6      2012      \N
# 1265781  tt9916690            7.8         7      2012      \N
# 1265782  tt9916730            8.0         8      2017      \N
# 1265783  tt9916766            7.0        21      2019      \N
# 1265784  tt9916778            7.2        36      2019      \N
#
#                              primaryTitle                     originalTitle  \
# 0                              Carmencita                        Carmencita
# ...

# %%
data.head()
# Out:
#       tconst  averageRating  numVotes startYear endYear  \
# 0  tt0000001            5.7      1936      1894      \N
# 1  tt0000002            5.8       262      1892      \N
# 2  tt0000003            6.5      1760      1892      \N
# 3  tt0000004            5.6       177      1892      \N
# 4  tt0000005            6.2      2570      1893      \N
#
#              primaryTitle           originalTitle                    genres
# 0              Carmencita              Carmencita         Documentary,Short
# 1  Le clown et ses chiens  Le clown et ses chiens           Animation,Short
# 2          Pauvre Pierrot          Pauvre Pierrot  Animation,Comedy,Romance
# 3             Un bon bock             Un bon bock           Animation,Short
# 4        Blacksmith Scene        Blacksmith Scene              Comedy,Short

# %%
data.tail()
# Out:
#             tconst  averageRating  numVotes startYear endYear  \
# 1265780  tt9916682            6.4         6      2012      \N
# 1265781  tt9916690            7.8         7      2012      \N
# 1265782  tt9916730            8.0         8      2017      \N
# 1265783  tt9916766            7.0        21      2019      \N
# 1265784  tt9916778            7.2        36      2019      \N
#
#                              primaryTitle                     originalTitle  \
# 1265780  Horrid Henry It's all Your Fault  Horrid Henry It's all Your Fault
# 1265781    Horrid Henry Delivers the Milk    Horrid Henry Delivers the Milk
# 1265782                            6 Gunn                            6 Gunn
# 1265783                    Episode #10.15                    Episode #10.15
# 1265784                            Escape                            Escape
#
#                               genres
# 1265780   Adventure,Animation,Comedy
# 1265781   Adventure,Animation,Comedy
# ...

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/yb/kt66bbqd7t7cb20rqwtk1yj40000gn/T/ipykernel_5193/1670796523.py in <module>
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.shape
# Out:
# (1265785, 8)

# %%
data.info
# Out:
# <bound method DataFrame.info of             tconst  averageRating  numVotes startYear endYear  \
# 0        tt0000001            5.7      1936      1894      \N
# 1        tt0000002            5.8       262      1892      \N
# 2        tt0000003            6.5      1760      1892      \N
# 3        tt0000004            5.6       177      1892      \N
# 4        tt0000005            6.2      2570      1893      \N
# ...            ...            ...       ...       ...     ...
# 1265780  tt9916682            6.4         6      2012      \N
# 1265781  tt9916690            7.8         7      2012      \N
# 1265782  tt9916730            8.0         8      2017      \N
# 1265783  tt9916766            7.0        21      2019      \N
# 1265784  tt9916778            7.2        36      2019      \N
#
#                              primaryTitle                     originalTitle  \
# 0                              Carmencita                        Carmencita
# ...

# %%
data.isnull().any()
# Out:
# tconst           False
# averageRating    False
# numVotes         False
# startYear        False
# endYear          False
# primaryTitle     False
# originalTitle    False
# genres            True
# dtype: bool

# %%
print("Any missing values? ", data.isnull().any())
# Out:
# Any missing values?  tconst           False
# averageRating    False
# numVotes         False
# startYear        False
# endYear          False
# primaryTitle     False
# originalTitle    False
# genres            True
# dtype: bool

# %%
data.isnull()
# Out:
#          tconst  averageRating  numVotes  startYear  endYear  primaryTitle  \
# 0         False          False     False      False    False         False
# 1         False          False     False      False    False         False
# 2         False          False     False      False    False         False
# 3         False          False     False      False    False         False
# 4         False          False     False      False    False         False
# ...         ...            ...       ...        ...      ...           ...
# 1265780   False          False     False      False    False         False
# 1265781   False          False     False      False    False         False
# 1265782   False          False     False      False    False         False
# 1265783   False          False     False      False    False         False
# 1265784   False          False     False      False    False         False
#
#          originalTitle  genres
# 0                False   False
# ...

# %%
data.isnull().sum()
# Out:
# tconst            0
# averageRating     0
# numVotes          0
# startYear         0
# endYear           0
# primaryTitle      0
# originalTitle     0
# genres           22
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data.isnull().sum()
# Out:
# tconst            0
# averageRating     0
# numVotes          0
# startYear         0
# endYear           0
# primaryTitle      0
# originalTitle     0
# genres           22
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
per_missing = data.isnull().sum() * 100 / len(data)
print(per_missing)
# Out:
# tconst           0.000000
# averageRating    0.000000
# numVotes         0.000000
# startYear        0.000000
# endYear          0.000000
# primaryTitle     0.000000
# originalTitle    0.000000
# genres           0.001738
# dtype: float64

# %%
print(data.isnull())
# Out:
#          tconst  averageRating  numVotes  startYear  endYear  primaryTitle  \
# 0         False          False     False      False    False         False
# 1         False          False     False      False    False         False
# 2         False          False     False      False    False         False
# 3         False          False     False      False    False         False
# 4         False          False     False      False    False         False
# ...         ...            ...       ...        ...      ...           ...
# 1265780   False          False     False      False    False         False
# 1265781   False          False     False      False    False         False
# 1265782   False          False     False      False    False         False
# 1265783   False          False     False      False    False         False
# 1265784   False          False     False      False    False         False
#
#          originalTitle  genres
# 0                False   False
# ...

# %%
data.loc[data.isnull().any(axis=1)]
# Out:
#              tconst  averageRating  numVotes startYear endYear  \
# 351242    tt0701219            8.4      2813        \N      30
# 463820   tt10383410            9.0        50        \N      \N
# 517892    tt1139253            5.7        18        \N      \N
# 522454   tt11488230            6.8         8        \N      24
# 554455   tt12149332            6.9         8        \N      \N
# 565583   tt12399100            7.5        44        \N      23
# 572253   tt12555738           10.0        23        \N      \N
# 674561   tt14829310            8.2        12        \N      \N
# 681391   tt15008902            3.6         5        \N      \N
# 770598   tt18260258           10.0         6        \N      \N
# 806567   tt20158838            4.4        12        \N      \N
# 869761    tt2360331            7.7        12        \N      30
# 933352    tt3235946            7.3        10        \N      47
# 980123    tt3945726            7.6        31        \N      \N
# ...

# %%
dup_data = data.duplicated().any()

# %%
print(dup_data)
# Out:
# False

# %%
data[data[['primaryTitle', 'startYear']].duplicated()]
# Out:
#             tconst  averageRating  numVotes startYear endYear  \
# 229      tt0000280            4.5        24      1900      \N
# 312      tt0000472            6.3        23      1903      \N
# 706      tt0001196            4.2         7      1910      \N
# 725      tt0001242            5.1        18      1908      \N
# 742      tt0001299            3.1        16      1909      \N
# ...            ...            ...       ...       ...     ...
# 1265756  tt9916170            7.0         7      2019      \N
# 1265760  tt9916204            8.2       251      2019      \N
# 1265767  tt9916362            6.4      5107      2020      \N
# 1265770  tt9916420            7.3         8      2019      \N
# 1265784  tt9916778            7.2        36      2019      \N
#
#                             primaryTitle                    originalTitle  \
# 229      Buffalo Bill's Wild West Parade  Buffalo Bill's Wild West Parade
# ...

# %%
data.to_csv('data.csv')

# %%
data[data[['primaryTitle', 'startYear']].duplicated()]
# Out:
#             tconst  averageRating  numVotes startYear endYear  \
# 229      tt0000280            4.5        24      1900      \N
# 312      tt0000472            6.3        23      1903      \N
# 706      tt0001196            4.2         7      1910      \N
# 725      tt0001242            5.1        18      1908      \N
# 742      tt0001299            3.1        16      1909      \N
# ...            ...            ...       ...       ...     ...
# 1265756  tt9916170            7.0         7      2019      \N
# 1265760  tt9916204            8.2       251      2019      \N
# 1265767  tt9916362            6.4      5107      2020      \N
# 1265770  tt9916420            7.3         8      2019      \N
# 1265784  tt9916778            7.2        36      2019      \N
#
#                             primaryTitle                    originalTitle  \
# 229      Buffalo Bill's Wild West Parade  Buffalo Bill's Wild West Parade
# ...

# %%
data[data[['primaryTitle', 'startYear']].duplicated()]
data.to_csv('duplicates.csv')

# %%
data.describe()
# Out:
#        averageRating      numVotes
# count   1.265785e+06  1.265785e+06
# mean    6.954938e+00  1.042796e+03
# std     1.386024e+00  1.733866e+04
# min     1.000000e+00  5.000000e+00
# 25%     6.200000e+00  1.200000e+01
# 50%     7.200000e+00  2.600000e+01
# 75%     7.900000e+00  1.020000e+02
# max     1.000000e+01  2.683241e+06

# %%
data.describe(include='all')
# Out:
#            tconst  averageRating      numVotes startYear  endYear  \
# count     1265785   1.265785e+06  1.265785e+06   1265785  1265785
# unique    1265785            NaN           NaN       260       89
# top     tt0000001            NaN           NaN      2019       \N
# freq            1            NaN           NaN     56927  1222753
# mean          NaN   6.954938e+00  1.042796e+03       NaN      NaN
# std           NaN   1.386024e+00  1.733866e+04       NaN      NaN
# min           NaN   1.000000e+00  5.000000e+00       NaN      NaN
# 25%           NaN   6.200000e+00  1.200000e+01       NaN      NaN
# 50%           NaN   7.200000e+00  2.600000e+01       NaN      NaN
# 75%           NaN   7.900000e+00  1.020000e+02       NaN      NaN
# max           NaN   1.000000e+01  2.683241e+06       NaN      NaN
#
#         primaryTitle originalTitle   genres
# count        1265785       1265785  1265763
# unique        950450        965128     2033
# ...

# %%
data.columns
# Out:
# Index(['tconst', 'averageRating', 'numVotes', 'startYear', 'endYear',
#        'primaryTitle', 'originalTitle', 'genres'],
#       dtype='object')

# %%
data.groupby('startYear')['averageRating']

# %%
data.groupby('startYear')['averageRating'].mean()
# Out:
# startYear
# 1892    5.966667
# 1893    6.200000
# 1894    5.516667
# 1895    5.466667
# 1896    4.630476
#           ...
# 2020    7.116868
# 2021    7.146945
# 2022    7.337886
# 2023    7.560297
# \N      7.276981
# Name: averageRating, Length: 260, dtype: float64

# %%
startYear_averageRating = data.groupby('startYear')['numVotes'].mean().sort_values(ascending=False)
startYear_averageRating.to_csv('averageRating_byYear.csv', sep='\t', encoding='utf-8')

# %%
data.columns
# Out:
# Index(['tconst', 'averageRating', 'numVotes', 'startYear', 'endYear',
#        'primaryTitle', 'originalTitle', 'genres'],
#       dtype='object')

# %%
avgRating_byYear = data.groupby('startYear')['averageRating'].mean()
avgRating_byYear.to_csv('avgRating_byYear.csv')

# %%
data.columns
# Out:
# Index(['tconst', 'averageRating', 'numVotes', 'startYear', 'endYear',
#        'primaryTitle', 'originalTitle', 'genres'],
#       dtype='object')

# %%
data['startYear'].value_counts()
# Out:
# 2019    56927
# 2018    55895
# 2017    55538
# 2016    53330
# 2021    51324
#         ...
# 2005        1
# 1893        1
# 1874        1
# 1883        1
# 1885        1
# Name: startYear, Length: 260, dtype: int64

# %%
data.groupby('primaryTitle')['averageRating'].count()
# Out:
# primaryTitle
# !Next?                         1
# !Que ve el Bisbe!              1
# !Women Art Revolution          1
# #                              2
# # My Ass                       1
#                               ..
# ärtico                         1
# él                             1
# êmîcêtôsêt: Many Bloodlines    1
# ö                              1
# Špansko the Continent          1
# Name: averageRating, Length: 950450, dtype: int64

# %%
data.groupby('startYear')['averageRating'].mean()
# Out:
# startYear
# 1892    5.966667
# 1893    6.200000
# 1894    5.516667
# 1895    5.466667
# 1896    4.630476
#           ...
# 2020    7.116868
# 2021    7.146945
# 2022    7.337886
# 2023    7.560297
# \N      7.276981
# Name: averageRating, Length: 260, dtype: float64

# %%
editing_writers = pd.read_csv('editing_writers.csv',sep='\t')

# %%
writers_profession = pd.read_csv('Writers_profession.csv', sep='\t')

# %%
directors_profession = pd.read_csv('director_name_3k_profession.csv')

# %%
top3k = pd.read_csv('3r_directors_and_writers.csv')

# %%
directors_and_writers.info()
directors_profession.info()
writers_profession.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3548 entries, 0 to 3547
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   primaryTitle  3548 non-null   object
#  1   tconst        3548 non-null   object
#  2   directors     3548 non-null   object
#  3   writers       3548 non-null   object
# dtypes: object(4)
# memory usage: 111.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2762 entries, 0 to 2761
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   primaryTitle       2762 non-null   object
#  1   tconst             2762 non-null   object
#  2   birthYear          2762 non-null   object
#  3   deathYear          2762 non-null   object
#  4   primaryName        2762 non-null   object
#  5   primaryProfession  2347 non-null   object
# dtypes: object(6)
# memory usage: 129.6+ KB
# ...

# %%
top3k.describe()
# Out:
#        primaryTitle     tconst directors writers
# count          3548       3548      3548    3548
# unique         3519       3548      2688    2642
# top     Ranganayaki  tt0008381        \N      \N
# freq              2          1        48     599

# %%
top_movies = pd.read_csv("isMovie_8Rating_100Votes.csv")

# %%
top_movies.describe(include='all')
# Out:
#        primaryTitle startYear  averageRating directors genres      numVotes  \
# count          3548      3548    3548.000000      3548   3548  3.548000e+03
# unique         3519       105            NaN      2688    350           NaN
# top     Ranganayaki      2022            NaN        \N  Drama           NaN
# freq              2       317            NaN        48    570           NaN
# mean            NaN       NaN       8.343856       NaN    NaN  5.769917e+04
# std             NaN       NaN       0.369700       NaN    NaN  2.219517e+05
# min             NaN       NaN       8.000000       NaN    NaN  1.010000e+02
# 25%             NaN       NaN       8.100000       NaN    NaN  2.030000e+02
# 50%             NaN       NaN       8.200000       NaN    NaN  7.825000e+02
# 75%             NaN       NaN       8.500000       NaN    NaN  6.201500e+03
# max             NaN       NaN      10.000000       NaN    NaN  2.683241e+06
#
# ...

# %%
top_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3548 entries, 0 to 3547
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   primaryTitle    3548 non-null   object
#  1   startYear       3548 non-null   object
#  2   averageRating   3548 non-null   float64
#  3   directors       3548 non-null   object
#  4   genres          3548 non-null   object
#  5   numVotes        3548 non-null   int64
#  6   originalTitle   3548 non-null   object
#  7   runtimeMinutes  3548 non-null   object
#  8   tconst          3548 non-null   object
#  9   writers         3548 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 277.3+ KB

# %%
data.columns
# Out:
# Index(['tconst', 'averageRating', 'numVotes', 'startYear', 'endYear',
#        'primaryTitle', 'originalTitle', 'genres'],
#       dtype='object')

# %%
a = data.groupby('genres')['averageRating'].mean()
a.to_csv('a.csv')

# %%
data.describe()
# Out:
#        averageRating      numVotes
# count   1.265785e+06  1.265785e+06
# mean    6.954938e+00  1.042796e+03
# std     1.386024e+00  1.733866e+04
# min     1.000000e+00  5.000000e+00
# 25%     6.200000e+00  1.200000e+01
# 50%     7.200000e+00  2.600000e+01
# 75%     7.900000e+00  1.020000e+02
# max     1.000000e+01  2.683241e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1265785 entries, 0 to 1265784
# Data columns (total 8 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1265785 non-null  object
#  1   averageRating  1265785 non-null  float64
#  2   numVotes       1265785 non-null  int64
#  3   startYear      1265785 non-null  object
#  4   endYear        1265785 non-null  object
#  5   primaryTitle   1265785 non-null  object
#  6   originalTitle  1265785 non-null  object
#  7   genres         1265763 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 77.3+ MB
